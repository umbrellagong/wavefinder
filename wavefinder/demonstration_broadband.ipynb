# %%
import numpy as np
from utility import generate_la_broad, plot_pdf, plot_groups_broad
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 16})

# %% [markdown]
# # detect groups from a single wave field

# %%
# Define wavefield parameters
kws_wave_spectrum = {'gamma':3, 'whether_Gaussian':False}
Hs = 12
Tp = 15
seed = 0

# %%
plot_groups_broad(seed, kws_wave_spectrum, Hs /2)

# %% [markdown]
# # Plot the PDF of L and A from a large number of detections

# %%
# groups are detected from wave fields with same parameters as above

# %%
results = np.load('data/broadband.npy', allow_pickle=True)
L, A = generate_la_broad(results, Hs=Hs, Tp=Tp)
xlim, ylim = (0, 12.1), (0.5, 1.2)
N = 10
plot_pdf(L, A, True, xlim, ylim, N)
